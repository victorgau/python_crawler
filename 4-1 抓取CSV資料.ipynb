# %% [markdown]
# <a href="https://colab.research.google.com/github/victorgau/python_crawler/blob/master/4-1%20%E6%8A%93%E5%8F%96CSV%E8%B3%87%E6%96%99.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 抓取CSV資料

# %% [markdown]
# CSV是Comma Separated Values的意思，它是一種使用逗號來分隔不同欄位資料的格式。
#
# 參考資料：
#
# * [Wikipedia - CSV](https://en.wikipedia.org/wiki/Comma-separated_values)
# * [CSV Files](https://people.sc.fsu.edu/~jburkardt/data/csv/csv.html)
# * [Free Sample Data for Database Load Testing](https://www.briandunning.com/sample-data/)
# * [高雄市公有路外停車場一覽表](https://data.kcg.gov.tw/dataset/department-of-transportation30/resource/fe3f93da-9673-4f7b-859c-9017d793f798)

# %%
import pandas as pd

# %%
df = pd.read_csv("https://data.kcg.gov.tw/dataset/449e45d9-dead-4873-95a9-cc34dabbb3af/resource/fe3f93da-9673-4f7b-859c-9017d793f798/download/108.6.21.csv")

# %%
df.head()

# %%
import folium
import geocoder

# %%
# 使用 geocoder 取得特定住址的 GPS 座標
location = geocoder.osm('高雄市').latlng

# %%
m = folium.Map(location=location, zoom_start=16)

# %%
for i, row in df.iterrows():
    try:
        folium.Marker([float(row['座標-緯度']), float(row['座標-經度'])], popup=row['停車場名稱']).add_to(m)
    except Exception as e:
        print(e.args)
# Out:
# ('Location values cannot contain NaNs, got:\n[nan, nan]',)
# ("could not convert string to float: '120.485.622'",)
# ('Location values cannot contain NaNs, got:\n[nan, nan]',)
# ('Location values cannot contain NaNs, got:\n[nan, nan]',)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## 讀取口罩剩餘數量明細

# %% [markdown]
# 參考連結：
#
# * https://data.nhi.gov.tw/Datasets/DatasetResource.aspx?rId=A21030000I-D50001-001

# %%
url = "http://data.nhi.gov.tw/Datasets/Download.ashx?rid=A21030000I-D50001-001&l=https://data.nhi.gov.tw/resource/mask/maskdata.csv"

# %%
import pandas as pd

# %%
df = pd.read_csv(url)

# %%
df[df['醫事機構地址'].str.contains("高雄市")]
# Out:
#          醫事機構代碼    醫事機構名稱                醫事機構地址       醫事機構電話  成人口罩剩餘數  \
# 22   5902022892      大有藥局         高雄市鼓山區文信路２３６號  (07)5529402     8172
# 23   5902040087      世詠藥局        高雄市楠梓區楠都東街１３８號  (07)3539869     2561
# 24   5902042657      皇慶藥局         高雄市楠梓區和光街１９１號  (07)3643352      224
# 25   5902050154      杏安藥局        高雄市三民區十全一路91 號  (07)3111606     3483
# 26   5902050298      瑞鶴藥局       高雄市三民區寶德里義德路２５號  (07)3862757     2502
# 27   5902051240      明皇藥局      高雄市三民區寶國里義華路１８１號  (07)3860121     1678
# 28   5902053833      建銘藥局         高雄市三民區吉林街２６２號  (07)3133460     2277
# 29   5902056807      長慶藥局         高雄市三民區金鼎路３１０號  (07)3105835     2103
# 30   5902057144     欣仁惠藥局        高雄市三民區大昌二路２４８號  (07)3837833     1973
# 31   5902080376      政德藥局       高雄市苓雅區正大里武廟路２９號  (07)7114371      855
# 32   5902080616      一加藥局         高雄市苓雅區和平一路四二號  (07)7212748     2230
# 33   5902083582      健智藥局       高雄市苓雅區四維二路９６之２號  (07)7249153     2856
